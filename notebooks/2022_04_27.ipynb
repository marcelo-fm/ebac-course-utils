# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Workshop** | Imersão em Python - Dia 2
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)<br>
# 27/04/2022
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Contexto;</li>
#   <li>Pacotes;</li>
#   <li>Análise; Exploratória</li>
#   <li>Desafio.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Workshop**

# %% [markdown]
# ## 1\. Contexto

# %% [markdown]
# ### **1.1. State of Data Brazil**

# %% [markdown]
# Pesquisa sobre o mercado de trabalho brasileiro de dados realizada pelo Data Hackers e pela Bain & Company. Mapeou o perfil atual das três maiores profissões da área de dados do Brasil: **engenheiro** de dados, **cientista** de dados e **analista** de dados. O relatório completo pode ser acessado neste [link](https://www.stateofdata.com.br/).

# %% [markdown]
# > **Figura 24**: Remuneração em 2021 por nível de cargo.

# %% [markdown]
# ![Screen Shot 2022-04-26 at 16.59.16.png](data:image/png;base64,...)

# %% [markdown]
# > Vamos tentar replicar esse gráfico até o final do *workshop* utilizado **Python**. Bora?

# %% [markdown]
# ### **1.2. Upload do notebook**

# %% [markdown]
# Vamos fazer o *download* deste *notebook* no **Kaggle** e o seu *upload* no **Google Colab**.

# %% [markdown]
#  - [Link](https://) para *download*.

# %% [markdown]
# ### **1.3. Aula anterior**

# %%
people = [
  {'level': 'Júnior', 'salary': 1500}, 
  {'level': 'Júnior', 'salary': 1200}, 
  {'level': 'Pleno',  'salary': 3000}, 
  {'level': 'Sênior', 'salary': 5000}
]

# %%
person = people[0]

print(person)
# Out:
# {'level': 'Júnior', 'salary': 1500}

# %%
level = person['level']
salary = person['salary']

print(level)
print(salary)
# Out:
# Júnior
# 1500

# %% [markdown]
# ## 2\. Pacotes

# %% [markdown]
# São códigos contribuidos pela comunidade.

# %% [markdown]
# ### **2.1. PyPI**

# %% [markdown]
# Repositório de pacotes Python.

# %% [markdown]
#  - [Link](https://pypi.org) para acesso.

# %% [markdown]
# ### **2.2. Pandas**

# %% [markdown]
# Pacote Python para manipulação de dados.

# %% [markdown]
# **Referências**

# %% [markdown]
#  - Cheat sheet ([link](https://python-graph-gallery.com/cheat-sheets/)).

# %% [markdown]
# **Instalação**:

# %% [markdown]
# Para instalar qualquer pacote Python do PyPi, basta utilizar o comando `pip install`.

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Exemplo**:

# %% [markdown]
# Criar uma lista com os salários de pessoas de dados de nível **Júnior**.

# %%
for person in people:
  print(person)
# Out:
# {'level': 'Júnior', 'salary': 1500}
# {'level': 'Júnior', 'salary': 1200}
# {'level': 'Pleno', 'salary': 3000}
# {'level': 'Sênior', 'salary': 5000}

# %% [markdown]
# Para utilizar um pacote instalado, precisamos importá-lo com o comando `import`.

# %%
import pandas as pd

# %% [markdown]
# A estrutura de dados principal do `Pandas` é o `DataFrame`, uma estrutura de dados tabular de duas dimensões.

# %%
people_df = pd.DataFrame(data=people)

# %%
people_df.head()
# Out:
#     level  salary
# 0  Júnior    1500
# 1  Júnior    1200
# 2   Pleno    3000
# 3  Sênior    5000

# %% [markdown]
# Para filtrar um `DataFrame`, basta utilizar o método `query` e uma operação lógica.

# %%
junior_df = people_df.query("level == 'Júnior'")

# %%
junior_df.head()
# Out:
#     level  salary
# 0  Júnior    1500
# 1  Júnior    1200

# %% [markdown]
# Para selecionar colunas de um `DataFrame`, basta utilizar a mesma notação de listas.

# %%
junior_salaries = junior_df['salary'].to_list()

# %%
print(junior_salaries)
# Out:
# [1500, 1200]

# %% [markdown]
# ### **2.3. Seaborn**

# %% [markdown]
# Pacote Python para visualização de dados.

# %% [markdown]
# **Referências**

# %% [markdown]
#  - Tutorial ([link](https://python-graph-gallery.com/seaborn/));
#  - Cheat sheet ([link](https://python-graph-gallery.com/cheat-sheets/));
#  - Visualizações em Python ([link](https://python-graph-gallery.com)).

# %% [markdown]
# **Instalação**:

# %% [markdown]
# Para instalar qualquer pacote Python do PyPi, basta utilizar o comando `pip install`.

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Exemplo**:

# %% [markdown]
# Criar uma lista com os salários de pessoas de dados de nível **Júnior**.

# %%
people_df.head()
# Out:
#     level  salary
# 0  Júnior    1500
# 1  Júnior    1200
# 2   Pleno    3000
# 3  Sênior    5000

# %% [markdown]
# Para utilizar um pacote instalado, precisamos importá-lo com o comando `import`.

# %%
import seaborn as sns

# %% [markdown]
# Existem diversos tipo de visualizações que o Seaborn suporta. Para o gráfico de barras, basta utilizar o método `barplot`.

# %%
# imprime o gráfico
plot = sns.barplot(x='level', y='salary', data=people_df, palette='pastel')

# configura o tamanho do gráfico
plot.figure.set_figwidth(15)
plot.figure.set_figheight(8)

# configura o título do gráfico e dos eixos
plot.set_xlabel('Salário médio por nível');
plot.set_xlabel('Nível');
plot.set_ylabel('Salário médio (R$)');

# %% [markdown]
# ## 3\. Análise Exploratória

# %% [markdown]
# A análise exploratória de dados é o processo de analisar e resumir um conjunto de dados, através do uso de técnicas estatísticas e de visualização de dados, para a extração de *insights*. É composta pelas seguintes etapas:

# %% [markdown]
# *   Extração;
# *   Exploração;
# *   Limpeza;
# *   Agregação;
# *   Visualização;
# *   *Storytelling*.

# %% [markdown]
# ### **2.1. Extração**

# %% [markdown]
# Na etapa de extração buscamos os dados de interesse na fonte em que são produzidos.

# %% [markdown]
# > Para obter os seus dados do relatório, basta fazer o seu *donwload* na página do **Kaggle** ([link](https://www.kaggle.com/datasets/datahackers/state-of-data-2021)) e o *upload* no **Google Colab**.

# %% [markdown]
# O relatório disponibiliza dados para seus usuários no formato `CSV`, um formato tabular de dados com cabeçalho (na primeira linha) e colunas separadas por vírgulas. Exemplo:
#
# ```csv
# "('P0', 'id')","('P1_a ', 'Idade')","('P1_a_a ', 'Faixa idade')",...
# qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s,38,35-39,...
# zdl2n19yhgpnoaco6kkczdl2nwv9zwrt,39,35-39,...
# vsamqp2un3q7us84mgvsams5fulsmcoh,30,30-34,...
# ```

# %% [markdown]
# Vamos ler os dados em um `DataFrame` `Pandas` utilizando o método `read_csv`.

# %%
report_df = pd.read_csv('./report.csv');
# Out:
# C:\Users\m_fos\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Vamos então visualizar as 10 primeiras linhas do `DataFrame`.

# %%
report_df.head(n=5)
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s                38.0
# 1  zdl2n19yhgpnoaco6kkczdl2nwv9zwrt                39.0
# 2  vsamqp2un3q7us84mgvsams5fulsmcoh                30.0
# 3  v31ab41botodnsv31zgg4k34zzojy81l                38.0
# 4  ubhu8ntvm4xc0sfkdubhu80e973eek0k                36.0
#
#   ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                      35-39           Masculino
# 1                      35-39           Masculino
# 2                      30-34           Masculino
# 3                      35-39            Feminino
# 4                      35-39           Masculino
#
#   ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 0                    Ceará (CE)                          CE
# 1                    Bahia (BA)                          BA
# 2           Santa Catarina (SC)                          SC
# 3                São Paulo (SP)                          SP
# ...

# %% [markdown]
# ### **2.2. Exploração**

# %% [markdown]
# Na etapa de exploração, buscamos entender as caraterísticas dos dados.

# %% [markdown]
#  - 5 primeiras linhas.

# %%
report_df.head(n=5)
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s                38.0
# 1  zdl2n19yhgpnoaco6kkczdl2nwv9zwrt                39.0
# 2  vsamqp2un3q7us84mgvsams5fulsmcoh                30.0
# 3  v31ab41botodnsv31zgg4k34zzojy81l                38.0
# 4  ubhu8ntvm4xc0sfkdubhu80e973eek0k                36.0
#
#   ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                      35-39           Masculino
# 1                      35-39           Masculino
# 2                      30-34           Masculino
# 3                      35-39            Feminino
# 4                      35-39           Masculino
#
#   ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 0                    Ceará (CE)                          CE
# 1                    Bahia (BA)                          BA
# 2           Santa Catarina (SC)                          SC
# 3                São Paulo (SP)                          SP
# ...

# %% [markdown]
#  - 5 últimas linhas.

# %%
report_df.tail(n=5)
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 2640  07nvo8cdy377a46gon207nvjebwe65zg                40.0
# 2641  01mqnby32u01pg3nuj6vipp4mc06s8pg                27.0
# 2642  01fncs8qbhl9zx01fncs8rqib2zl3d18                24.0
# 2643  075h3v2z19if04yn7o075h3vhifl38rw                38.0
# 2644  037usz1h2yip96dgil4mhj037uszw1gk                27.0
#
#      ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 2640                      40-44           Masculino
# 2641                      25-29           Masculino
# 2642                      22-24           Masculino
# 2643                      35-39           Masculino
# 2644                      25-29            Feminino
#
#      ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 2640                São Paulo (SP)                          SP
# 2641           Santa Catarina (SC)                          SC
# 2642           Santa Catarina (SC)                          SC
# ...

# %% [markdown]
#  - Número de linhas e colunas.

# %%
report_df.shape
# Out:
# (2645, 356)

# %% [markdown]
#  - Nome das colunas.

# %%
report_df.columns
# Out:
# Index(['('P0', 'id')', '('P1_a ', 'Idade')', '('P1_a_a ', 'Faixa idade')',
#        '('P1_b ', 'Genero')', '('P1_e ', 'Estado onde mora')',
#        '('P1_e_a ', 'uf onde mora')', '('P1_e_b ', 'Regiao onde mora')',
#        '('P1_g_b ', 'Regiao de origem')', '('P1_g_c ', 'Mudou de Estado?')',
#        '('P1_h ', 'Nivel de Ensino')',
#        ...
#        '('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')',
#        '('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')',
#        '('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')',
#        '('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')',
#        '('P9_a_a ', 'Blog/Medium do Data Hackers')',
#        '('P9_a_b ', 'Podcast do Data Hackers')',
#        '('P9_a_d ', 'Newsletter Semanal')', '('P9_a_e ', 'Canal do Slack')',
# ...

# %% [markdown]
#  - Tipo do dado.

# %%
report_df.dtypes
# Out:
# ('P0', 'id')                                         object
# ('P1_a ', 'Idade')                                  float64
# ('P1_a_a ', 'Faixa idade')                           object
# ('P1_b ', 'Genero')                                  object
# ('P1_e ', 'Estado onde mora')                        object
#                                                      ...
# ('P9_a_b ', 'Podcast do Data Hackers')                int64
# ('P9_a_d ', 'Newsletter Semanal')                     int64
# ('P9_a_e ', 'Canal do Slack')                         int64
# ('P9_a_f ', 'Canal do Youtube do Data Hackers')       int64
# ('P9_a_g ', 'Ainda não conhecia o Data Hackers')      int64
# Length: 356, dtype: object

# %% [markdown]
# ### **2.3. Limpeza**

# %% [markdown]
# Na etapa de limpeza, processamos os dados para que fiquem consistentes.

# %% [markdown]
#  - **Selecionar as colunas de interesse.**

# %% [markdown]
# Extrair as colunas do `DataFrame` em uma lista.

# %%
reports_columns = report_df.columns.to_list()

# %%
reports_columns[0:5]
# Out:
# ["('P0', 'id')",
#  "('P1_a ', 'Idade')",
#  "('P1_a_a ', 'Faixa idade')",
#  "('P1_b ', 'Genero')",
#  "('P1_e ', 'Estado onde mora')"]

# %% [markdown]
# Depois de explorar o nome das colunas, encontrar as que representam o nível e o salário.

# %%
reports_columns[17]
# Out:
# "('P2_g ', 'Nivel')"

# %%
reports_columns[18]
# Out:
# "('P2_h ', 'Faixa salarial')"

# %% [markdown]
# Então, filtramos os `DataFrame` original através da seleção das colunas de interesse.

# %%
report_clean_df = report_df[["('P2_g ', 'Nivel')", "('P2_h ', 'Faixa salarial')"]]

# %%
report_clean_df.head()
# Out:
#   ('P2_g ', 'Nivel')       ('P2_h ', 'Faixa salarial')
# 0                NaN    de R$ 4.001/mês a R$ 6.000/mês
# 1                NaN    de R$ 6.001/mês a R$ 8.000/mês
# 2                NaN   de R$ 8.001/mês a R$ 12.000/mês
# 3                NaN  de R$ 12.001/mês a R$ 16.000/mês
# 4                NaN   de R$ 8.001/mês a R$ 12.000/mês

# %% [markdown]
#  - **Ajustar o nome das colunas.**

# %% [markdown]
# Extrair as colunas do `DataFrame` em uma lista.

# %%
reports_columns = report_clean_df.columns.to_list()

# %%
reports_columns
# Out:
# ["('P2_g ', 'Nivel')", "('P2_h ', 'Faixa salarial')"]

# %% [markdown]
# Limpar as `string` com os nomes das colunas.

# %%
reports_clean_columns = []

for reports_column in reports_columns:

  clean_column = (reports_column
                  .split(sep=',')[-1]
                  .strip()
                  .replace("'", "")
                  .replace(")", "")
                  .lower()
  )
  
  reports_clean_columns.append(clean_column)

# %%
reports_clean_columns
# Out:
# ['nivel', 'faixa salarial']

# %% [markdown]
# Substituir as colunas originais pelas limpas.

# %%
report_clean_df.columns = reports_clean_columns

# %%
report_clean_df.head()
# Out:
#   nivel                    faixa salarial
# 0   NaN    de R$ 4.001/mês a R$ 6.000/mês
# 1   NaN    de R$ 6.001/mês a R$ 8.000/mês
# 2   NaN   de R$ 8.001/mês a R$ 12.000/mês
# 3   NaN  de R$ 12.001/mês a R$ 16.000/mês
# 4   NaN   de R$ 8.001/mês a R$ 12.000/mês

# %% [markdown]
#  - **Remover os valores nulos.**

# %% [markdown]
# Observar a ocorrencia de valores nulos em ambas as colunas

# %%
report_clean_df['nivel'].value_counts(dropna=False)
# Out:
# NaN       788
# Pleno     658
# Júnior    621
# Sênior    578
# Name: nivel, dtype: int64

# %%
report_clean_df['faixa salarial'].value_counts(dropna=False)
# Out:
# de R$ 8.001/mês a R$ 12.000/mês     479
# de R$ 4.001/mês a R$ 6.000/mês      403
# de R$ 6.001/mês a R$ 8.000/mês      393
# NaN                                 280
# de R$ 12.001/mês a R$ 16.000/mês    263
# de R$ 3.001/mês a R$ 4.000/mês      183
# de R$ 2.001/mês a R$ 3000/mês       180
# de R$ 16.001/mês a R$ 20.000/mês    129
# de R$ 1.001/mês a R$ 2.000/mês      126
# de R$ 20.001/mês a R$ 25.000/mês     62
# de R$ 25.001/mês a R$ 30.000/mês     43
# de R$ 30.001/mês a R$ 40.000/mês     38
# Acima de R$ 40.001/mês               34
# Menos de R$ 1.000/mês                32
# Name: faixa salarial, dtype: int64

# %% [markdown]
# Remover todas as colunas com valores nulos.

# %%
report_clean_df = report_clean_df.dropna()

# %%
report_clean_df['nivel'].value_counts(dropna=False)
# Out:
# Pleno     658
# Júnior    621
# Sênior    578
# Name: nivel, dtype: int64

# %%
report_clean_df['faixa salarial'].value_counts(dropna=False)
# Out:
# de R$ 8.001/mês a R$ 12.000/mês     378
# de R$ 4.001/mês a R$ 6.000/mês      371
# de R$ 6.001/mês a R$ 8.000/mês      332
# de R$ 2.001/mês a R$ 3000/mês       173
# de R$ 3.001/mês a R$ 4.000/mês      171
# de R$ 12.001/mês a R$ 16.000/mês    157
# de R$ 1.001/mês a R$ 2.000/mês      122
# de R$ 16.001/mês a R$ 20.000/mês     59
# Menos de R$ 1.000/mês                24
# de R$ 20.001/mês a R$ 25.000/mês     20
# de R$ 30.001/mês a R$ 40.000/mês     20
# de R$ 25.001/mês a R$ 30.000/mês     18
# Acima de R$ 40.001/mês               12
# Name: faixa salarial, dtype: int64

# %% [markdown]
# Observar a redução do número de linhas.

# %%
report_df.shape
# Out:
# (2645, 356)

# %%
report_clean_df.shape
# Out:
# (1857, 2)

# %% [markdown]
# ### **2.4. Agregação**

# %% [markdown]
# Na etapa de agregação, buscamos resumir os dados através de métricas estatísticas como soma, média, etc. para extrair *insights*.

# %% [markdown]
#  - **Contar as faixas salariais por nível**

# %% [markdown]
# Adicionamos uma coluna chamada `soma` com o valor igual a 1.

# %%
report_clean_df['soma'] = 1

# %%
report_clean_df.head()
# Out:
#       nivel                  faixa salarial  soma
# 482  Sênior  de R$ 6.001/mês a R$ 8.000/mês     1
# 483   Pleno  de R$ 6.001/mês a R$ 8.000/mês     1
# 484  Júnior  de R$ 4.001/mês a R$ 6.000/mês     1
# 485   Pleno  de R$ 4.001/mês a R$ 6.000/mês     1
# 486   Pleno  de R$ 6.001/mês a R$ 8.000/mês     1

# %% [markdown]
# Agregamos as colunas de `nível` e faixa `salarial` através da soma da coluna `soma`.

# %%
report_clean_df = report_clean_df.groupby(['nivel', 'faixa salarial']).sum('soma').reset_index()

# %%
report_clean_df.head(20)
# Out:
#      nivel                    faixa salarial  soma
# 0   Júnior             Menos de R$ 1.000/mês    22
# 1   Júnior    de R$ 1.001/mês a R$ 2.000/mês   112
# 2   Júnior  de R$ 12.001/mês a R$ 16.000/mês     4
# 3   Júnior     de R$ 2.001/mês a R$ 3000/mês   139
# 4   Júnior  de R$ 20.001/mês a R$ 25.000/mês     1
# 5   Júnior    de R$ 3.001/mês a R$ 4.000/mês   114
# 6   Júnior  de R$ 30.001/mês a R$ 40.000/mês     1
# 7   Júnior    de R$ 4.001/mês a R$ 6.000/mês   160
# 8   Júnior    de R$ 6.001/mês a R$ 8.000/mês    41
# 9   Júnior   de R$ 8.001/mês a R$ 12.000/mês    27
# 10   Pleno            Acima de R$ 40.001/mês     2
# 11   Pleno             Menos de R$ 1.000/mês     2
# 12   Pleno    de R$ 1.001/mês a R$ 2.000/mês     9
# 13   Pleno  de R$ 12.001/mês a R$ 16.000/mês    26
# 14   Pleno  de R$ 16.001/mês a R$ 20.000/mês    11
# 15   Pleno     de R$ 2.001/mês a R$ 3000/mês    28
# 16   Pleno  de R$ 20.001/mês a R$ 25.000/mês     6
# ...

# %% [markdown]
#  - **Ordernar as faixas salariais**

# %% [markdown]
# Manualmente definir a ordem das faixa salariais em um dicionário.

# %%
report_clean_df['faixa salarial'].drop_duplicates().to_dict()
# Out:
# {0: 'Menos de R$ 1.000/mês',
#  1: 'de R$ 1.001/mês a R$ 2.000/mês',
#  2: 'de R$ 12.001/mês a R$ 16.000/mês',
#  3: 'de R$ 2.001/mês a R$ 3000/mês',
#  4: 'de R$ 20.001/mês a R$ 25.000/mês',
#  5: 'de R$ 3.001/mês a R$ 4.000/mês',
#  6: 'de R$ 30.001/mês a R$ 40.000/mês',
#  7: 'de R$ 4.001/mês a R$ 6.000/mês',
#  8: 'de R$ 6.001/mês a R$ 8.000/mês',
#  9: 'de R$ 8.001/mês a R$ 12.000/mês',
#  10: 'Acima de R$ 40.001/mês',
#  14: 'de R$ 16.001/mês a R$ 20.000/mês',
#  17: 'de R$ 25.001/mês a R$ 30.000/mês'}

# %%
faixa_salarial_ordenada = [
  {'ordem': 0,'faixa salarial': 'Menos de R$ 1.000/mês'},
  {'ordem': 1,'faixa salarial': 'de R$ 1.001/mês a R$ 2.000/mês'},
  {'ordem': 2,'faixa salarial': 'de R$ 2.001/mês a R$ 3000/mês'},
  {'ordem': 3,'faixa salarial': 'de R$ 3.001/mês a R$ 4.000/mês'},
  {'ordem': 4,'faixa salarial': 'de R$ 4.001/mês a R$ 6.000/mês'},
  {'ordem': 5,'faixa salarial': 'de R$ 6.001/mês a R$ 8.000/mês'},
  {'ordem': 6,'faixa salarial': 'de R$ 8.001/mês a R$ 12.000/mês'},
  {'ordem': 7,'faixa salarial': 'de R$ 12.001/mês a R$ 16.000/mês'},
  {'ordem': 8,'faixa salarial': 'de R$ 16.001/mês a R$ 20.000/mês'},
  {'ordem': 9,'faixa salarial': 'de R$ 20.001/mês a R$ 25.000/mês'},
  {'ordem': 10,'faixa salarial': 'de R$ 25.001/mês a R$ 30.000/mês'},
  {'ordem': 11,'faixa salarial': 'de R$ 30.001/mês a R$ 40.000/mês'},
  {'ordem': 12,'faixa salarial': 'Acima de R$ 40.001/mês'}
]

# %% [markdown]
# Criar um `DataFrame` com o dicionário.

# %%
faixa_salarial_ordenada_df = pd.DataFrame(faixa_salarial_ordenada)

# %%
faixa_salarial_ordenada_df.head(12)
# Out:
#     ordem                    faixa salarial
# 0       0             Menos de R$ 1.000/mês
# 1       1    de R$ 1.001/mês a R$ 2.000/mês
# 2       2     de R$ 2.001/mês a R$ 3000/mês
# 3       3    de R$ 3.001/mês a R$ 4.000/mês
# 4       4    de R$ 4.001/mês a R$ 6.000/mês
# 5       5    de R$ 6.001/mês a R$ 8.000/mês
# 6       6   de R$ 8.001/mês a R$ 12.000/mês
# 7       7  de R$ 12.001/mês a R$ 16.000/mês
# 8       8  de R$ 16.001/mês a R$ 20.000/mês
# 9       9  de R$ 20.001/mês a R$ 25.000/mês
# 10     10  de R$ 25.001/mês a R$ 30.000/mês
# 11     11  de R$ 30.001/mês a R$ 40.000/mês

# %% [markdown]
# Combinar com o `DataFrame` do relatório.

# %%
report_clean_df = report_clean_df.merge(faixa_salarial_ordenada_df, on=['faixa salarial'], how='left')

# %%
report_clean_df.head(20)
# Out:
#      nivel                    faixa salarial  soma  ordem
# 0   Júnior             Menos de R$ 1.000/mês    22      0
# 1   Júnior    de R$ 1.001/mês a R$ 2.000/mês   112      1
# 2   Júnior  de R$ 12.001/mês a R$ 16.000/mês     4      7
# 3   Júnior     de R$ 2.001/mês a R$ 3000/mês   139      2
# 4   Júnior  de R$ 20.001/mês a R$ 25.000/mês     1      9
# 5   Júnior    de R$ 3.001/mês a R$ 4.000/mês   114      3
# 6   Júnior  de R$ 30.001/mês a R$ 40.000/mês     1     11
# 7   Júnior    de R$ 4.001/mês a R$ 6.000/mês   160      4
# 8   Júnior    de R$ 6.001/mês a R$ 8.000/mês    41      5
# 9   Júnior   de R$ 8.001/mês a R$ 12.000/mês    27      6
# 10   Pleno            Acima de R$ 40.001/mês     2     12
# 11   Pleno             Menos de R$ 1.000/mês     2      0
# 12   Pleno    de R$ 1.001/mês a R$ 2.000/mês     9      1
# 13   Pleno  de R$ 12.001/mês a R$ 16.000/mês    26      7
# 14   Pleno  de R$ 16.001/mês a R$ 20.000/mês    11      8
# ...

# %% [markdown]
# Ordernar por nível e ordem.

# %%
report_clean_df = report_clean_df.sort_values(['nivel', 'ordem'], ascending=[True, True]).reset_index()

# %%
report_clean_df.head(20)
# Out:
#     index   nivel                    faixa salarial  soma  ordem
# 0       0  Júnior             Menos de R$ 1.000/mês    22      0
# 1       1  Júnior    de R$ 1.001/mês a R$ 2.000/mês   112      1
# 2       3  Júnior     de R$ 2.001/mês a R$ 3000/mês   139      2
# 3       5  Júnior    de R$ 3.001/mês a R$ 4.000/mês   114      3
# 4       7  Júnior    de R$ 4.001/mês a R$ 6.000/mês   160      4
# 5       8  Júnior    de R$ 6.001/mês a R$ 8.000/mês    41      5
# 6       9  Júnior   de R$ 8.001/mês a R$ 12.000/mês    27      6
# 7       2  Júnior  de R$ 12.001/mês a R$ 16.000/mês     4      7
# 8       4  Júnior  de R$ 20.001/mês a R$ 25.000/mês     1      9
# 9       6  Júnior  de R$ 30.001/mês a R$ 40.000/mês     1     11
# 10     11   Pleno             Menos de R$ 1.000/mês     2      0
# 11     12   Pleno    de R$ 1.001/mês a R$ 2.000/mês     9      1
# 12     15   Pleno     de R$ 2.001/mês a R$ 3000/mês    28      2
# ...

# %% [markdown]
# ## 4\. Desafio

# %% [markdown]
# Agora é com você, utilize o `DataFrame` construído e o pacote de visualização de dados Seaborn para gerar o gráfico abaixo que apresenta a quantidade de pessoas por nível por faixa salarial.

# %% [markdown]
# > **Dica 1.** Utilize o exemplo da sessão 2.3.
#
# > **Dica 2.** Utilize o parametro hue para a coluna `faixa salarial`.

# %% [markdown]
# ![Unknown-2.png](data:image/png;base64,...)

# %% [markdown]
# Substitua os três pontos (...) abaixo pelo seu código.

# %%
# imprime o gráfico
plot = None
plot = sns.barplot(x='nivel', y='soma', data=report_clean_df, hue='faixa salarial', palette='muted') #...

# configura o tamanho do gráfico
plot.figure.set_figwidth(20)
plot.figure.set_figheight(11.5)

plot.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# configura o título do gráfico e dos eixos
plot.set_xlabel('Quantidade de pessoas por nível por faixa salarial');
plot.set_xlabel('Nível');
plot.set_ylabel('Quantidade');

#sns.set(font_scale=2) #já escalonado
